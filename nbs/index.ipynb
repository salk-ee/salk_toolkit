# %%
#| hide
from salk_toolkit.core import *

# %% [markdown]
# # salk_toolkit
#
# > Common tools and functions useful in multiple different workflows and dashboards

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install salk_toolkit
# ```

# %% [markdown]
# ## How to use
#
# ### Data specification
#
# Here we will describe how to format and describe your data meta for visualisations.
